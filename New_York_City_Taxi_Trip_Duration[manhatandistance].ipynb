# %% [markdown]
# # New York City Taxi Trip Duration

# %% [markdown]
# ### Goal : predicts the total ride duration of taxi trips in New York City.
# ### Evaluation Metric : Root Mean Squared Logarithmic Error. [ RMLSE ]

# %% [markdown]
# ## 1. Bring the data

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('data/train.csv', parse_dates = ["pickup_datetime",'dropoff_datetime'])
test = pd.read_csv('data/test.csv',parse_dates = ['pickup_datetime'])

# %%
print(train.shape)
train.head(5)
# Out:
# (1458644, 11)
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %%
print(test.shape)
test.head(5)
# Out:
# (625134, 9)
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id3004672          1 2016-06-30 23:59:58                1
# 1  id3505355          1 2016-06-30 23:59:53                1
# 2  id1217141          1 2016-06-30 23:59:47                1
# 3  id2150126          2 2016-06-30 23:59:41                1
# 4  id1598245          1 2016-06-30 23:59:33                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.988129        40.732029         -73.990173         40.756680
# 1        -73.964203        40.679993         -73.959808         40.655403
# 2        -73.997437        40.737583         -73.986160         40.729523
# 3        -73.956070        40.771900         -73.986427         40.730469
# 4        -73.970215        40.761475         -73.961510         40.755890
#
#   store_and_fwd_flag
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N

# %% [markdown]
# ## 2. Look around data / EDA

# %% [markdown]
# ### 1) value confirm

# %%
train.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag'],
#       dtype='object')

# %% [markdown]
# ### Value
#
# #### id - a unique identifier for each trip
# #### vendor_id - a code indicating the provider associated with the trip record
# #### pickup_datetime - date and time when the meter was engaged
# #### dropoff_datetime - date and time when the meter was disengaged
# #### passenger_count - the number of passengers in the vehicle (driver entered value)
# #### pickup_longitude - the longitude where the meter was engaged
# #### pickup_latitude - the latitude where the meter was engaged
# #### dropoff_longitude - the longitude where the meter was disengaged
# #### dropoff_latitude - the latitude where the meter was disengaged
# #### store_and_fwd_flag - This flag indicates whether the trip record was held in vehicle memory before sending to the vendor because the vehicle did not have a connection to the server - Y=store and forward; ;N=not a store and forward trip
# #### trip_duration - duration of the trip in seconds

# %% [markdown]
# ### 2) comfirm missing data

# %%
train.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# dtype: int64

# %% [markdown]
# ### 2-1) visualization missing data

# %%
import missingno as msno

msno.matrix(df = train, figsize = (30,15), color = (0.12, 0.5, 0.5))

# color = (RGB[0~1],RGB_brighten[0~],mix_color )

# %%
msno.matrix(df=test, figsize = (30,15), color = (0.9, 0.3, 0.01))

# %% [markdown]
# ### 2-2) correlation with heatamp

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cor_matrix = train.corr().round(2)

fig = plt.figure(figsize = (20,20));
sns.heatmap(cor_matrix, annot =True , center = 0,
           cmap = sns.diverging_palette(250,10,as_cmap = True),
           ax = plt.subplot(111));

plt.show()

# %% [markdown]
# ### 2-3) make some variables

# %%
train['pickup_datetime'].head()
# Out:
# 0   2016-03-14 17:24:55
# 1   2016-06-12 00:43:35
# 2   2016-01-19 11:35:24
# 3   2016-04-06 19:32:31
# 4   2016-03-26 13:30:55
# Name: pickup_datetime, dtype: datetime64[ns]

# %% [markdown]
#  #### pickup_datetime variables

# %%
train['pickup_year'] = train['pickup_datetime'].dt.year  
train['pickup_month'] = train['pickup_datetime'].dt.month
train['pickup_day'] = train['pickup_datetime'].dt.day
train['pickup_hour'] = train['pickup_datetime'].dt.hour
train['pickup_minute'] = train['pickup_datetime'].dt.minute
train['pickup_second'] = train['pickup_datetime'].dt.second
train["pickup_dayofweek"] = train["pickup_datetime"].dt.dayofweek 

train[['pickup_year','pickup_month', 'pickup_day','pickup_hour','pickup_minute','pickup_second', 'pickup_dayofweek']].head()
# Out:
#    pickup_year  pickup_month  pickup_day  pickup_hour  pickup_minute  \
# 0         2016             3          14           17             24
# 1         2016             6          12            0             43
# 2         2016             1          19           11             35
# 3         2016             4           6           19             32
# 4         2016             3          26           13             30
#
#    pickup_second  pickup_dayofweek
# 0             55                 0
# 1             35                 6
# 2             24                 1
# 3             31                 2
# 4             55                 5

# %%
# 'test data' doesn`t have dropoff_datetime 

test['pickup_year'] = test['pickup_datetime'].dt.year  
test['pickup_month'] = test['pickup_datetime'].dt.month
test['pickup_day'] = test['pickup_datetime'].dt.day
test['pickup_hour'] = test['pickup_datetime'].dt.hour
test['pickup_minute'] = test['pickup_datetime'].dt.minute
test['pickup_second'] = test['pickup_datetime'].dt.second
test["pickup_dayofweek"] = test["pickup_datetime"].dt.dayofweek 

test[['pickup_year','pickup_month', 'pickup_day','pickup_hour','pickup_minute','pickup_second', 'pickup_dayofweek']].head()
# Out:
#    pickup_year  pickup_month  pickup_day  pickup_hour  pickup_minute  \
# 0         2016             6          30           23             59
# 1         2016             6          30           23             59
# 2         2016             6          30           23             59
# 3         2016             6          30           23             59
# 4         2016             6          30           23             59
#
#    pickup_second  pickup_dayofweek
# 0             58                 3
# 1             53                 3
# 2             47                 3
# 3             41                 3
# 4             33                 3

# %% [markdown]
# ### *basic distance from two coordinates

# %%
from math import sin, cos, sqrt, atan2, radians # approximate radius of earth in km 
import numpy as np

def haversine(train):
    lon1 = train['pickup_longitude']
    lat1 = train['pickup_latitude']
    lon2 = train['dropoff_longitude']
    lat2 = train['dropoff_latitude']
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * np.arcsin(sqrt(a)) 
    km = 6367 * c
    return km

train['distance'] = train.apply(lambda train: haversine(train), axis=1)
train
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0        id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1        id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2        id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3        id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4        id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
# 5        id0801584          2 2016-01-30 22:01:40 2016-01-30 22:09:03
# 6        id1813257          1 2016-06-17 22:34:59 2016-06-17 22:40:40
# 7        id1324603          2 2016-05-21 07:54:58 2016-05-21 08:20:49
# 8        id1301050          1 2016-05-27 23:12:23 2016-05-27 23:16:38
# 9        id0012891          2 2016-03-10 21:45:01 2016-03-10 22:05:26
# 10       id1436371          2 2016-05-10 22:08:41 2016-05-10 22:29:55
# 11       id1299289          2 2016-05-15 11:16:11 2016-05-15 11:34:59
# 12       id1187965          2 2016-02-19 09:52:46 2016-02-19 10:11:20
# 13       id0799785          2 2016-06-01 20:58:29 2016-06-01 21:02:49
# 14       id2900608          2 2016-05-27 00:43:36 2016-05-27 01:07:10
# 15       id3319787          1 2016-05-16 15:29:02 2016-05-16 15:32:33
# 16       id3379579          2 2016-04-11 17:29:50 2016-04-11 18:08:26
# 17       id1154431          1 2016-04-14 08:48:26 2016-04-14 09:00:37
# 18       id3552682          1 2016-06-27 09:55:13 2016-06-27 10:17:10
# 1458628            351         2016             5          30            3
# 1458629            601         2016             6          24           10
# 1458630            549         2016             6          25            3
# 1458631            342         2016             5          14           23
# 1458632            777         2016             3           6           11
# 1458633            979         2016             3          17           19
# 1458634            972         2016             4           3           13
# 1458635            237         2016             5          19           14
# 1458636            800         2016             2          12           10
# 1458637            760         2016             4          17           18
# 1458638            414         2016             2           2            0
# 1458639            778         2016             4           8           13
# 1458640            655         2016             1          10            7
# 1458641            764         2016             4          22            6
# 1458642            373         2016             1           5           15
# 1458643            198         2016             4           5           14
#
#          pickup_minute  pickup_second  pickup_dayofweek   distance
# 0                   24             55                 0   1.497580
# 1                   43             35                 6   1.804374
# 2                   35             24                 1   6.381090
# 3                   32             31                 2   1.484566
# 4                   30             55                 5   1.187842
# 5                    1             40                 5   1.098252
# 6                   34             59                 4   1.325446
# 7                   54             58                 5   5.711393
# 8                   12             23                 4   1.309531
# 9                   45              1                 3   5.117946
# 10                   8             41                 1   3.803750
# 11                  16             11                 6   3.770727
# 12                  52             46                 4   1.858316
# 13                  58             29                 2   0.991062
# 14                  43             36                 4   6.378828
# 15                  29              2                 0   0.656166
# 16                  29             50                 0   3.425934
# 17                  48             26                 3   2.537078
# 18                  55             13                 0   4.602310
# 19                  47             23                 6   1.302453
# 20                  23              2                 6   2.504353
# 21                  12             25                 4   1.723467
# 22                  34             27                 5   2.065787
# 23                  36             26                 5   4.871732
# 24                  15              5                 4  20.589640
# 25                  27             56                 6   4.556662
# 26                  56              1                 5   6.052307
# 27                   7             16                 0   3.736395
# 28                  57             27                 0   2.523264
# 29                  10             39                 2   9.933202
# ...                ...            ...               ...        ...
# 1458614             16              7                 0   1.341817
# 1458615             57              8                 4   2.764834
# 1458616             21             14                 4   0.979457
# 1458617             31             20                 4   0.655256
# 1458618             46             48                 6   1.171270
# 1458619             14             15                 5   2.258316
# 1458620             51              3                 3   4.137718
# 1458621             33             30                 0   4.401336
# 1458622             26             52                 4   0.729293
# 1458623             35             30                 0   1.667979
# 1458624             21              4                 1   0.778857
# 1458625             21             15                 0   3.656954
# 1458626             21             11                 6   1.284819
# 1458627             10             28                 3   2.176778
# 1458628              8             19                 0   1.357925
# 1458629             33             51                 4   2.557842
# 1458630             44             32                 5   1.559349
# 1458631             18             23                 5   1.873316
# 1458632              4             48                 6   3.973047
# 1458633             10             16                 3   3.030208
# 1458634             51             25                 6   5.255687
# 1458635             46             55                 3   0.616594
# 1458636             13              6                 4   0.930065
# 1458637             48             16                 6   3.535334
# 1458638             39             39                 1   2.315993
# 1458639             31              4                 4   1.224311
# 1458640             35             15                 6   6.046037
# 1458641             57             41                 4   7.819693
# 1458642             56             26                 1   1.091878
# 1458643             44             25                 1   1.133330
#
# [1458644 rows x 19 columns]

# %%
import numpy as np

def haversine(test):
    lon1 = test['pickup_longitude']
    lat1 = test['pickup_latitude']
    lon2 = test['dropoff_longitude']
    lat2 = test['dropoff_latitude']
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 
# 28              30           23             52             15
# 29              30           23             51             42
# ...            ...          ...            ...            ...
# 625104           1            0             13             21
# 625105           1            0             11             38
# 625106           1            0             11             33
# 625107           1            0             11             10
# 625108           1            0             10             40
# 625109           1            0             10             15
# 625110           1            0             10              9
# 625111           1            0             10              2
# 625112           1            0              9             44
# 625113           1            0              9             40
# 625114           1            0              9             17
# 625115           1            0              8             38
# 625116           1            0              8             36
# 625117           1            0              8             30
# 625118           1            0              7             20
# 625119           1            0              7             13
# 625120           1            0              6             57
# 625121           1            0              6              0
# 625122           1            0              5             39
# 625123           1            0              5             14
# 625124           1            0              5             12
# 625125           1            0              5              2
# 625126           1            0              5              1
# 625127           1            0              3             38
# 625128           1            0              3              0
# 625129           1            0              2             52
# 625130           1            0              1             52
# 625131           1            0              1             24
# 625132           1            0              0             28
# 625133           1            0              0             22
#
#         pickup_dayofweek   distance
# 0                      3   2.744701
# 1                      3   2.757507
# 2                      3   1.305335
# 3                      3   5.265780
# 4                      3   0.960239
# 5                      3   4.183643
# 6                      3   3.510409
# 7                      3   2.979082
# 8                      3  18.840335
# 9                      3   1.818872
# 10                     3   4.750163
# 11                     3   0.787825
# 12                     3   1.523470
# 13                     3   2.608931
# 14                     3   5.432713
# 15                     3   4.804138
# 16                     3   3.587669
# 17                     3   1.747576
# 18                     3   0.690007
# 19                     3   5.557726
# 20                     3   0.740499
# 21                     3   1.982892
# 22                     3   1.703037
# 23                     3   4.740886
# 24                     3   5.237160
# 25                     3   7.527734
# 26                     3   2.504801
# 27                     3   1.099670
# 28                     3  10.229728
# 29                     3   7.998662
# ...                  ...        ...
# 625104                 4   1.486501
# 625105                 4   1.352838
# 625106                 4   2.326767
# 625107                 4   1.599585
# 625108                 4   7.829491
# 625109                 4   3.276839
# 625110                 4   0.623984
# 625111                 4   4.103469
# 625112                 4   1.428087
# 625113                 4   2.010822
# 625114                 4   1.887174
# 625115                 4  15.919745
# 625116                 4   2.459905
# 625117                 4   9.147508
# 625118                 4   5.834864
# 625119                 4   1.509209
# 625120                 4   1.519072
# 625121                 4   0.855445
# 625122                 4   1.212625
# 625123                 4   6.048324
# 625124                 4   3.069544
# 625125                 4   3.311829
# 625126                 4   1.248289
# 625127                 4   1.550009
# 625128                 4   0.769547
# 625129                 4   0.966830
# 625130                 4   6.192453
# 625131                 4   8.148600
# 625132                 4  20.367952
# 625133                 4   5.928295
#
# [625134 rows x 17 columns]

# %% [markdown]
# ### *manhatandistnace from two coordinates

# %%
from math import sin, cos, sqrt, atan2, radians
# 지구 반지름 : 6367 km

# 경도 1도의 거리(km단위) = cos(위도)*6380 *2 * 3.14159 /360

# 위도 1도의 거리(km단위) = 6380 *2 *3.14159 /360

# 위도가 40도 일때 경도 1도의 거리
latitude_40 = cos(40)*6380 *2 * 3.14159 /360
latitude_40

print(latitude_40)
# 위도는 위치에 관계없이 약 111km 이다. 위도 : lattitude 경도 : longitude
# Out:
# -74.2648284987617

# %%
import numpy as np
train.loc[:,'man_distance'] = np.abs((train['pickup_latitude'] - train['dropoff_latitude'])*111)+ 
                              np.abs((train['pickup_longitude']-train['dropoff_longitude'])*85.397)
    
test.loc[:,'man_distance'] = np.abs((test['pickup_latitude'] - test['dropoff_latitude'])*111)+ 
                              np.abs((test['pickup_longitude']-test['dropoff_longitude'])*85.397)

train.head(5)
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag      ...       pickup_year  \
# 0         40.765602                  N      ...              2016
# 1         40.731152                  N      ...              2016
# 2         40.710087                  N      ...              2016
# 3         40.706718                  N      ...              2016
# 4         40.782520                  N      ...              2016
#
#    pickup_month  pickup_day  pickup_hour  pickup_minute  pickup_second  \
# 0             3          14           17             24             55
# 1             6          12            0             43             35
# 2             1          19           11             35             24
# 3             4           6           19             32             31
# 4             3          26           13             30             55
#
#    pickup_dayofweek  distance  man_dist3  man_distance
# 0                 0  1.497580   1.755698      1.755698
# 1                 6  1.804374   2.450894      2.450894
# 2                 1  6.381090   8.224048      8.224048
# 3                 2  1.484566   1.661247      1.661247
# 4                 5  1.187842   1.197531      1.197531
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2-4) one_hot_encoding

# %%
train['store_and_fwd_flag_Y'] = train['store_and_fwd_flag'] == 'Y'
train['store_and_fwd_flag_N'] = train['store_and_fwd_flag'] == 'N'

train[['store_and_fwd_flag', 'store_and_fwd_flag_Y', 'store_and_fwd_flag_N']].head()
# Out:
#   store_and_fwd_flag  store_and_fwd_flag_Y  store_and_fwd_flag_N
# 0                  N                 False                  True
# 1                  N                 False                  True
# 2                  N                 False                  True
# 3                  N                 False                  True
# 4                  N                 False                  True

# %%
test['store_and_fwd_flag_Y'] = test['store_and_fwd_flag'] == 'Y'
test['store_and_fwd_flag_N'] = test['store_and_fwd_flag'] == 'N'

test[['store_and_fwd_flag', 'store_and_fwd_flag_Y', 'store_and_fwd_flag_N']].head()
# Out:
#   store_and_fwd_flag  store_and_fwd_flag_Y  store_and_fwd_flag_N
# 0                  N                 False                  True
# 1                  N                 False                  True
# 2                  N                 False                  True
# 3                  N                 False                  True
# 4                  N                 False                  True

# %% [markdown]
# ### 2-5) Visualization

# %% [markdown]
# #### 'datetime' for 'trip_duration'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows = 2, ncols = 3)
figure.set_size_inches(16,9)

sns.barplot(data = train, x = 'pickup_month', y = 'trip_duration', ax = ax1)
sns.barplot(data = train, x = 'pickup_day', y = 'trip_duration', ax = ax2)
sns.barplot(data = train, x = 'pickup_hour', y = 'trip_duration', ax = ax3)
sns.barplot(data = train, x = 'pickup_minute', y = 'trip_duration', ax = ax4)
sns.barplot(data = train, x = 'pickup_second', y = 'trip_duration', ax = ax5)
sns.barplot(data = train, x = 'pickup_dayofweek', y = 'trip_duration', ax = ax6)

# %% [markdown]
# #### 'vender_id, 'store_and_fwd_flag' for 'trip_duration

# %%
figure, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2)
figure.set_size_inches(16,9)

sns.barplot(data = train, x = 'vendor_id', y = 'trip_duration', ax = ax1)
sns.barplot(data = train, x = 'store_and_fwd_flag', y = 'trip_duration', ax = ax2)

# %% [markdown]
# #### 'passenger_count' for 'trip_duration'

# %%
sns.barplot(data = train , hue = 'vendor_id', x = 'passenger_count', y= 'trip_duration' )

# %%
train.head(5)
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag          ...           pickup_day  \
# 0         40.765602                  N          ...                   14
# 1         40.731152                  N          ...                   12
# 2         40.710087                  N          ...                   19
# 3         40.706718                  N          ...                    6
# 4         40.782520                  N          ...                   26
#
#    pickup_hour  pickup_minute  pickup_second  pickup_dayofweek  distance  \
# 0           17             24             55                 0  1.497580
# 1            0             43             35                 6  1.804374
# 2           11             35             24                 1  6.381090
# 3           19             32             31                 2  1.484566
# 4           13             30             55                 5  1.187842
#
#    man_dist3  man_distance  store_and_fwd_flag_Y  store_and_fwd_flag_N
# 0   1.755698      1.755698                 False                  True
# 1   2.450894      2.450894                 False                  True
# 2   8.224048      8.224048                 False                  True
# 3   1.661247      1.661247                 False                  True
# 4   1.197531      1.197531                 False                  True
#
# [5 rows x 23 columns]

# %%
test.head(5)
# Out:
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id3004672          1 2016-06-30 23:59:58                1
# 1  id3505355          1 2016-06-30 23:59:53                1
# 2  id1217141          1 2016-06-30 23:59:47                1
# 3  id2150126          2 2016-06-30 23:59:41                1
# 4  id1598245          1 2016-06-30 23:59:33                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.988129        40.732029         -73.990173         40.756680
# 1        -73.964203        40.679993         -73.959808         40.655403
# 2        -73.997437        40.737583         -73.986160         40.729523
# 3        -73.956070        40.771900         -73.986427         40.730469
# 4        -73.970215        40.761475         -73.961510         40.755890
#
#   store_and_fwd_flag  pickup_year          ...           pickup_day  \
# 0                  N         2016          ...                   30
# 1                  N         2016          ...                   30
# 2                  N         2016          ...                   30
# 3                  N         2016          ...                   30
# 4                  N         2016          ...                   30
#
#    pickup_hour  pickup_minute  pickup_second  pickup_dayofweek  distance  \
# 0           23             59             58                 3  2.744701
# 1           23             59             53                 3  2.757507
# 2           23             59             47                 3  1.305335
# 3           23             59             41                 3  5.265780
# 4           23             59             33                 3  0.960239
#
#    man_dist3  man_distance  store_and_fwd_flag_Y  store_and_fwd_flag_N
# 0   2.910823      2.910823                 False                  True
# 1   3.104719      3.104719                 False                  True
# 2   1.857668      1.857668                 False                  True
# 3   7.191316      7.191316                 False                  True
# 4   1.363296      1.363296                 False                  True
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 4. select features and change data

# %% [markdown]
# #### 4-1) select features

# %%
train.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration', 'pickup_year', 'pickup_month', 'pickup_day',
#        'pickup_hour', 'pickup_minute', 'pickup_second', 'pickup_dayofweek',
#        'distance', 'man_dist3', 'man_distance', 'store_and_fwd_flag_Y',
#        'store_and_fwd_flag_N'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag', 'pickup_year', 'pickup_month',
#        'pickup_day', 'pickup_hour', 'pickup_minute', 'pickup_second',
#        'pickup_dayofweek', 'distance', 'man_dist3', 'man_distance',
#        'store_and_fwd_flag_Y', 'store_and_fwd_flag_N'],
#       dtype='object')

# %%
feature_names = [ 'vendor_id',
                 'passenger_count', 'pickup_longitude', 'pickup_latitude',
                 'dropoff_longitude', 'dropoff_latitude',
                 'pickup_year', 'pickup_month', 'pickup_day', 'pickup_hour', 
                 'pickup_minute', 'pickup_second', 'pickup_dayofweek',
                 'store_and_fwd_flag_Y', 'store_and_fwd_flag_N','man_distance' ]

# %% [markdown]
# #### 4-2) data change

# %%
x_train = train[feature_names]
print(x_train.shape)
x_train.head()
# Out:
# (1458644, 16)
#    vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# 0          2                1        -73.982155        40.767937
# 1          1                1        -73.980415        40.738564
# 2          2                1        -73.979027        40.763939
# 3          2                1        -74.010040        40.719971
# 4          2                1        -73.973053        40.793209
#
#    dropoff_longitude  dropoff_latitude  pickup_year  pickup_month  pickup_day  \
# 0         -73.964630         40.765602         2016             3          14
# 1         -73.999481         40.731152         2016             6          12
# 2         -74.005333         40.710087         2016             1          19
# 3         -74.012268         40.706718         2016             4           6
# 4         -73.972923         40.782520         2016             3          26
#
#    pickup_hour  pickup_minute  pickup_second  pickup_dayofweek  \
# 0           17             24             55                 0
# 1            0             43             35                 6
# 2           11             35             24                 1
# 3           19             32             31                 2
# 4           13             30             55                 5
#
#    store_and_fwd_flag_Y  store_and_fwd_flag_N  man_distance
# 0                 False                  True      1.755698
# 1                 False                  True      2.450894
# 2                 False                  True      8.224048
# 3                 False                  True      1.661247
# 4                 False                  True      1.197531

# %%
x_test = test[feature_names]
print(x_test.shape)
x_test.head(5)
# Out:
# (625134, 16)
#    vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# 0          1                1        -73.988129        40.732029
# 1          1                1        -73.964203        40.679993
# 2          1                1        -73.997437        40.737583
# 3          2                1        -73.956070        40.771900
# 4          1                1        -73.970215        40.761475
#
#    dropoff_longitude  dropoff_latitude  pickup_year  pickup_month  pickup_day  \
# 0         -73.990173         40.756680         2016             6          30
# 1         -73.959808         40.655403         2016             6          30
# 2         -73.986160         40.729523         2016             6          30
# 3         -73.986427         40.730469         2016             6          30
# 4         -73.961510         40.755890         2016             6          30
#
#    pickup_hour  pickup_minute  pickup_second  pickup_dayofweek  \
# 0           23             59             58                 3
# 1           23             59             53                 3
# 2           23             59             47                 3
# 3           23             59             41                 3
# 4           23             59             33                 3
#
#    store_and_fwd_flag_Y  store_and_fwd_flag_N  man_distance
# 0                 False                  True      2.910823
# 1                 False                  True      3.104719
# 2                 False                  True      1.857668
# 3                 False                  True      7.191316
# 4                 False                  True      1.363296

# %%
y_train = train['trip_duration']
print(y_train.shape)
y_train.head()
# Out:
# (1458644,)
# 0     455
# 1     663
# 2    2124
# 3     429
# 4     435
# Name: trip_duration, dtype: int64

# %% [markdown]
# ### 5. Machine Learning

# %% [markdown]
# #### Evaluation Metric : RMSLE

# %%
# before learning it, should take something it

# %%
import numpy as np

y_train = np.log(y_train+1)
print(y_train.shape)
y_train.head()

# it will show better score
# Out:
# (1458644,)
# 0    6.122493
# 1    6.498282
# 2    7.661527
# 3    6.063785
# 4    6.077642
# Name: trip_duration, dtype: float64

# %% [markdown]
# #### 5-1) Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state = 37)
model
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=37, splitter='best')

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=37, splitter='best')

# %% [markdown]
# #### *** after fitting model must do this thing

# %%
## predictions = np.exp(predictions) - 1
## predictions[0:10]

# %%
predictions = model.predict(x_test)
predictions = np.exp(predictions) - 1
print(predictions.shape)
predictions[0:10]
# Out:
# (625134,)
# array([  873.,  1067.,   531.,  1136.,   398.,  1423.,  1312.,   545.,
#         1657.,   518.])

# %% [markdown]
# #### submit

# %%
submission = pd.read_csv("sample_submission.csv")
submission['trip_duration'] = predictions

submission.to_suv("DecisionTree.csv", index = False)

# %% [markdown]
# ### * Cross Validation
# ####  U will wondering am i doing right ? before get scoring
# #### that moment Cross Validation help U
# #### this competition Evaluation Function is EMSLE so makes function like that

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmsle(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)
# log_predict = np.log(predict + 1)
# log_actual = np.log(actual + 1)
    log_predict = predict + 1
    log_actual = actual + 1
    difference = log_predict - log_actual
    difference = np.square(difference)  
    mean_difference = difference.mean() 
    score = np.sqrt(mean_difference)
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %% [markdown]
# #### 5-2) Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=12)
model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=12, verbose=0, warm_start=False)

# %%
## if U want to modify parameters 
## Do it like that and add some parameters or modify something u want

# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor(random_state=50, n_estimators = 600, max_depth = 10, n_jobs = 10)
# model

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=12, verbose=0, warm_start=False)

# %% [markdown]
# #### after fitting model and u can confirm the Score preview using Cross Validation
#
# #### U should know this Score just reference so don`t be sure of it

# %%
# after fitting model and u can comfirm the Scroe preview using Cross Validation

from sklearn.model_selection import cross_val_score

score = cross_val_score(model, x_train, y_train, cv = 3, scoring=rmsle_scorer).mean()
score
# Out:
# 0.43806897321497446

# %%
predictions = model.predict(x_test)
predictions = np.exp(predictions) - 1
print(predictions.shape)
predictions[0:10]
# Out:
# (625134,)
# array([  761.68502648,   449.25795221,   595.03987809,  1001.37481004,
#         1031.47169878,   943.7277381 ,  1455.1148751 ,  1648.00838574,
#         2123.46581658,   674.8264923 ])

# %% [markdown]
# #### submit

# %%
submission = pd.read_csv("data/sample_submission.csv")
submission["trip_duration"] = predictions

submission.to_csv("Random_Forest.csv", index=False)

# %%
import xgboost as xgb

print(xgb)
# Out:
# <module 'xgboost' from 'C:\\Anaconda3\\lib\\site-packages\\xgboost\\__init__.py'>

# %% [markdown]
# ### 5-3) XGBoost

# %%
import xgboost as xgb

model = xgb.XGBRegressor(n_estimators = 100, learning_rate = 0.01).fit(x_train,y_train)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.model_selection import cross_val_score

score = cross_val_score(model, x_train, y_train, cv = 2, scoring=rmsle_scorer).mean()
score
# Out:
# 2.3003408097383913

# %%
predictions = model.predict(x_test)
predictions = np.exp(predictions) - 1
print(predictions.shape)
predictions[:10]
# Out:
# (625134,)
# array([  65.96507263,   78.66068268,   65.96507263,   65.96507263,
#          65.96507263,   65.96507263,   73.97637177,   73.97637177,
#         126.83488464,   65.96507263], dtype=float32)

# %% [markdown]
# #### submit

# %%
submission = pd.read_csv("sample_submission.csv")
submission["trip_duration"] = predictions

submission.to_csv('XGBoost.csv', index = False)
